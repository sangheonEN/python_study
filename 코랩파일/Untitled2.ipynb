# %%
print("가나다")

a = 10
a = input('값을 입력해라')
type(a)
# Out:
# 가나다
# 값을 입력해라8
# str

# %%
a = ['1', '2', '3', '4']
print(a[0])
type(a[0])
# Out:
# 1
# int

# %%
import keyword

keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
#cel = int(input('섭씨온도를 입력해라 : '))
cel = input('섭씨온도를 입력하세요 : ')
#a = type(cel)
print(a)
fah = int(cel) * 1.8 + 32                                                # 리터럴 누가봐도 숫자인것을 안다. 
print('섭씨 온도' ,cel,'은 화씨온도 : ', fah,'입니다.')
# Out:
# 섭씨온도를 입력하세요 : 4
# <class 'str'>
# 섭씨 온도 4 은 화씨온도 :  39.2 입니다.

# %%
price = input('가격 : ')
num = input('개수 : ')
sum = int(price) * num
print('총 액 :', sum, '원')
type(sum)
type(price)
type(num)
# Out:
# 가격 : 1000
# 개수 : 1
# 총 액 : ... 원
# str

# %%
a = 10
b = 20
temp = a
a = b
b = temp

print(a, b, temp)
# Out:
# 20 10 10

# %%
x = 5
print(x)
y = x
x = 29
print(x)
print(y)
# Out:
# 5
# 29
# 5

# %%
ord('a')
# Out:
# 97
